# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from Votes import wide as df
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import joblib

warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\874307239.py in <module>
#       4 import seaborn as sns
#       5 import warnings
# ----> 6 from Votes import wide as df
#       7 from sklearn.model_selection import train_test_split
#       8 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'Votes'

# %%
data = pd.read_csv('imdb_data.csv')
data.head()
# Out:
#    Sno                                         Movie Name  \
# 0    1                                    The Dark Knight
# 1    2      The Lord of the Rings: The Return of the King
# 2    3                Spider-Man: Across the Spider-Verse
# 3    4                                          Inception
# 4    5  The Lord of the Rings: The Fellowship of the Ring
#
#                                        Director Name Duration  Year  Ratings  \
# 0  Christopher Nolan, Christian Bale, Heath Ledge...  152 min  2008      9.0
# 1  Peter Jackson, Elijah Wood, Viggo Mortensen, I...  201 min  2003      9.0
# 2  Joaquim Dos Santos, Kemp Powers, Justin K. Tho...  140 min  2023      8.9
# 3  Christopher Nolan, Leonardo DiCaprio, Joseph G...  148 min  2010      8.8
# 4  Peter Jackson, Elijah Wood, Ian McKellen, Orla...  178 min  2001      8.8
#
#    Metascore                                              Stars    Votes  \
# 0       84.0  Christian Bale, Heath Ledger, Aaron Eckhart, M...  2751275
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Votes'])
plt.title('Votes', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Gross Collection'])
plt.title('Gross Collection', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data['Votes'])
plt.title('Votes', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(35,15))
plt.subplot(data['Gross Collection'])
plt.title('Gross Collection', fontsize=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7176\2387189934.py in <module>
#       1 plt.figure(figsize=(35,15))
# ----> 2 plt.subplot(data['Gross Collection'])
#       3 plt.title('Gross Collection', fontsize=25)
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1287
#    1288     # First, search for an existing subplot with a matching spec.
# -> 1289     key = SubplotSpec._from_subplot_args(fig, args)
#    1290
#    1291     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     580                 return arg
#     581             elif not isinstance(arg, Integral):
# --> 582                 raise ValueError(
#     583                     f"Single argument to subplot must be a three-digit "
# ...
